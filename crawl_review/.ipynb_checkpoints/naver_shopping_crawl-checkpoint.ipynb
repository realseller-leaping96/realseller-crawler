# %% [markdown]
# # 1. 엑셀데이터 불러오기

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import numpy as np
import re


df_input = pd.read_csv('phone_info.csv')
df_input.iloc[0]
# Out:
# pl_id                   1
# pl_maker            apple
# pl_group            apple
# pl_model_code       A2221
# pl_name             아이폰11
# pl_model_name    iphone11
# Name: 0, dtype: object

# %% [markdown]
# # 2. 리뷰크롤링

# %%
import time
#####################################################################################
######################### 크롤링 데이터 초기화 ######################################
#####################################################################################
my_dict = {
    "pl_id": "",                      #스펙테이블 아이디
    "pl_model_code": "",              #모델코드
    "pl_name": "",                    #모델영문명
    
    "star": "",                       #별점
    "market": "",                     #구입처(ex 인터파크, 11번가)
    "write_id": "",                   #작성자(일부가림처리)
    "upload_day": "",                 #업로드날짜
    "title":"",                       #리뷰제목 
    "text": ""                        #리뷰내용 
}

crawl_data = pd.DataFrame(my_dict,index=[0])
crawl_data_none = pd.DataFrame(my_dict,index=[0])
#######################################################################################
#######################################################################################
#######################################################################################

def search_by_category(df_input,crawl_data,index,option):
    if option == "skt":
        url1 = 'https://search.shopping.naver.com/search/category?catId=50000246&frm=NVSHMDL&iq='
    elif option == "kt":
        url1 = 'https://search.shopping.naver.com/search/category?catId=50000247&frm=NVSHMDL&iq='
    elif option == "lg":
        url1 = 'https://search.shopping.naver.com/search/category?catId=50000248&frm=NVSHMDL&iq='
    else:
        url1 = 'https://search.shopping.naver.com/search/category?catId=50000204&frm=NVSHMDL&iq='
    url2 = '&origQuery&pagingIndex=1&pagingSize=40&productSet=model&query&sort=rel&timestamp=&viewType=list'
    driver.get(url1+df_input.iloc[index][4]+url2)
    driver.implicitly_wait(3)
    
    
    #페이지에 있는 링크 다 긁어오기, 일단 스크롤기능 추가안해서 5개만 가져옴 => 5개 넘어가면 검색정확도 떨어져서 고정
    req = driver.page_source
    soup=BeautifulSoup(req, 'html.parser')
    div_list = soup.select(".basicList_info_area__17Xyo")
    
    link_list = []
    for i in range(len(div_list)):
        if div_list[i].select("div.basicList_info_area__17Xyo > div.basicList_etc_box__1Jzg6 > a") == []:
            pass
        else:
            link_list.append(div_list[i].select(".basicList_link__1MaTN")[0])
    

    for link in link_list:
        url = 'window.open("' + link.get('href') +'");'
        driver.execute_script(url)
        driver.switch_to.window(driver.window_handles[-1])
        req = driver.page_source
        soup=BeautifulSoup(req, 'html.parser')
        review_list = soup.select(".reviewItems_list_review__1sgcJ")
        review_list = review_list[0].find_all("li")
        
        for review in review_list:
            area1 = review.select(".reviewItems_etc_area__2P8i3")
            area1 = area1[0].find_all("span")
            
            star = area1[0].text.replace("평점","") 
            market = area1[3].text 
            write_id = area1[4].text 
            upload_day = area1[5].text 
            
            area2 = review.select(".reviewItems_review_text__2Bwpa")
            title = area2[0].select(".reviewItems_title__39Z8H")[0].text
            text = area2[0].select(".reviewItems_text__XIsTc")[0].text
            
            my_dict = {
                "pl_id": df_input.iloc[index][0],              #기종아이디(자체부여한것)
                "pl_model_code": df_input.iloc[index][3],      #모델코드
                "pl_name": df_input.iloc[index][4],            #모델영문명

                "star": star,                       #별점
                "market": market,                   #구입처(ex 인터파크, 11번가)
                "write_id": write_id,               #작성자(일부가림처리)
                "upload_day": upload_day,           #업로드날짜
                "title":title,                      #리뷰제목 
                "text": text,                       #리뷰내용 
            }
            
            if my_dict is None or my_dict == None:
                pass
            else:
                a = pd.DataFrame(my_dict,index=[0])
                crawl_data = crawl_data.append(a)
        
        # 현재 탭 닫기
        driver.close()
        # 맨 처음 탭으로 변경(0번 탭)
        driver.switch_to.window(driver.window_handles[0])
    #display(crawl_data)
    return crawl_data

# 초기화 --------------------------------------------
chrome_options = Options()
chrome_options.add_argument("--headless")
driver  = webdriver.Chrome('../chromedriver')
driver.implicitly_wait(3)


for i in range(150,180):
#     print("=================",i,"skt","=================")
#     crawl_data = crawl_data.append(search_by_category(df_input,crawl_data_none,i,"skt")) 
#     print("=================",i,"kt","=================")
#     crawl_data = crawl_data.append(search_by_category(df_input,crawl_data_none,i,"kt"))
#     print("=================",i,"lg","=================")
#     crawl_data = crawl_data.append(search_by_category(df_input,crawl_data_none,i,"lg"))
    crawl_data = crawl_data.append(search_by_category(df_input,crawl_data_none,i,"all"))
    
crawl_data = crawl_data[crawl_data['pl_id'] != '']
crawl_data = crawl_data.reset_index(drop=True)

# %%
import pandas as pd
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 5000)
pd.set_option('display.max_columns', 100)
display(crawl_data)
# Out:
# pandas version:  1.0.5
#    pl_id pl_model_code       pl_name star        market  write_id upload_day  \
# 1    152       LG-F540            볼트    4                jsmj****  11.08.08.
# 2    152       LG-F540            볼트    3                qwer****  11.04.12.
# 3    152       LG-F540            볼트    5                sh38****  11.03.30.
# 4    152       LG-F540            볼트    1                ywol****  11.02.22.
# 5    152       LG-F540            볼트    5                you0****  11.02.22.
# 6    152       LG-F540            볼트    1                zero****  11.02.22.
# 7    152       LG-F540            볼트    5                vksa****  11.03.01.
# 8    152       LG-F540            볼트    1                sumo****  11.01.18.
# 9    152       LG-F540            볼트    1                hent****  11.01.19.
# 10   152       LG-F540            볼트    5                fast****  11.01.12.
# 1    154       LM-Q925            Q9    5                faf*****  20.04.10.
# 2    154       LM-Q925            Q9    5                msl*****  19.08.15.
# 3    154       LM-Q925            Q9    5            옥션  zero****  19.08.28.
# 4    154       LM-Q925            Q9    5          11번가  no******  19.11.24.
# 5    154       LM-Q925            Q9    5          인터파크  z*l*****  20.02.12.
# 6    154       LM-Q925            Q9    4                bes*****  19.01.29.
# 7    154       LM-Q925            Q9    4                lwj*****  19.09.30.
# 8    154       LM-Q925            Q9    4          인터파크  djan****  19.03.26.
# 9    154       LM-Q925            Q9    3                mej*****  19.02.06.
# 10   154       LM-Q925            Q9    5                sah*****  20.04.20.
# 11   154       LM-Q925            Q9    5         SSG닷컴  ls******  20.07.12.
# 12   154       LM-Q925            Q9    5          11번가  la******  20.06.09.
# 13   154       LM-Q925            Q9    5          11번가  83******  20.05.24.
# 14   154       LM-Q925            Q9    5          인터파크  c*d*****  20.02.12.
# 15   154       LM-Q925            Q9    5          11번가  km******  20.05.24.
# 16   154       LM-Q925            Q9    5          11번가  km******  20.05.24.
# 17   154       LM-Q925            Q9    5                chy*****  19.12.12.
# 18   154       LM-Q925            Q9    5          인터파크  s*o*****  20.04.18.
# 19   154       LM-Q925            Q9    5          인터파크  e*e*****  20.04.01.
# 20   154       LM-Q925            Q9    5                chl*****  19.12.04.
# 21   154       LM-Q925            Q9    5            옥션  s*l*****  20.07.26.
# 22   154       LM-Q925            Q9    5            옥션  h*r*****  20.05.12.
# 23   154       LM-Q925            Q9    4            옥션  q*q*****  20.03.28.
# 24   154       LM-Q925            Q9    5            옥션  c*l*****  20.02.13.
# 25   154       LM-Q925            Q9    5         롯데홈쇼핑  jan*****  19.06.15.
# 26   154       LM-Q925            Q9    5            옥션  k*s*****  20.01.16.
# 27   154       LM-Q925            Q9    5            옥션  flot****  19.09.28.
# 1    155       LM-Q927        Q9 One    5            옥션  flot****  19.09.28.
# 1    156       LM-Q815       Q8 2018    5                chy*****  19.11.26.
# 2    156       LM-Q815       Q8 2018    5                hjc*****  19.11.20.
# 3    156       LM-Q815       Q8 2018    5                wbe*****  19.11.23.
# 4    156       LM-Q815       Q8 2018    5                yol*****  19.10.26.
# 5    156       LM-Q815       Q8 2018    5                jon*****  19.11.10.
# 6    156       LM-Q815       Q8 2018    5                fro*****  19.11.18.
# 7    156       LM-Q815       Q8 2018    5                gra*****  19.11.27.
# 8    156       LM-Q815       Q8 2018    5          인터파크  ruda****  18.11.25.
# 1    157      LGM-X800            Q8    5                chy*****  19.11.26.
# 2    157      LGM-X800            Q8    5                hjc*****  19.11.20.
# 3    157      LGM-X800            Q8    5                wbe*****  19.11.23.
# 4    157      LGM-X800            Q8    5                yol*****  19.10.26.
# 5    157      LGM-X800            Q8    5                jon*****  19.11.10.
# 6    157      LGM-X800            Q8    5                fro*****  19.11.18.
# 7    157      LGM-X800            Q8    5                gra*****  19.11.27.
# 8    157      LGM-X800            Q8    5          인터파크  ruda****  18.11.25.
# 1    158        LMQ710      Q Stylus    5                chy*****  19.11.26.
# 2    158        LMQ710      Q Stylus    5                hjc*****  19.11.20.
# 3    158        LMQ710      Q Stylus    5                wbe*****  19.11.23.
# 4    158        LMQ710      Q Stylus    5                yol*****  19.10.26.
# 5    158        LMQ710      Q Stylus    5                jon*****  19.11.10.
# 6    158        LMQ710      Q Stylus    5                fro*****  19.11.18.
# 7    158        LMQ710      Q Stylus    5                gra*****  19.11.27.
# 8    158        LMQ710      Q Stylus    5          인터파크  ruda****  18.11.25.
# 1    160       LM-Q720            Q7    5          인터파크  4*5*****  19.09.05.
# 2    160       LM-Q720            Q7    3            옥션  inky****  19.04.04.
# 3    160       LM-Q720            Q7    5          인터파크  chw*****  19.03.08.
# 4    160       LM-Q720            Q7    5       하이마트쇼핑몰  t*n*****  19.06.23.
# 1    161       LM-Q725       Q7 Plus    5       하이마트쇼핑몰  t*n*****  19.06.23.
# 1    162       LG-X600            Q6    5          인터파크  na******  18.05.30.
# 2    162       LG-X600            Q6    5          인터파크  gip*****  17.11.10.
# 1    164       LM-V500     V50 ThinQ    5         SSG닷컴  sj******  20.03.05.
# 2    164       LM-V500     V50 ThinQ    5            옥션  v*o*****  21.02.18.
# 3    164       LM-V500     V50 ThinQ    5          인터파크  g*e*****  20.07.15.
# 4    164       LM-V500     V50 ThinQ    5          11번가  ca******  20.06.05.
# 5    164       LM-V500     V50 ThinQ    4           G마켓  g*w*****  20.05.12.
# 6    164       LM-V500     V50 ThinQ    5           G마켓  s*h*****  20.04.29.
# 7    164       LM-V500     V50 ThinQ    5          인터파크  e*d*****  19.10.10.
# 8    164       LM-V500     V50 ThinQ    5           G마켓  ryou****  19.05.23.
# 9    164       LM-V500     V50 ThinQ    4                kby*****  19.06.21.
# 10   164       LM-V500     V50 ThinQ    5           G마켓  kar1****  19.05.23.
# 11   164       LM-V500     V50 ThinQ    5            옥션  mini****  19.05.23.
# 12   164       LM-V500     V50 ThinQ    5            옥션  audg****  19.05.23.
# 13   164       LM-V500     V50 ThinQ    5           G마켓  tndu****  19.05.29.
# 14   164       LM-V500     V50 ThinQ    5           G마켓  you*****  19.05.28.
# 15   164       LM-V500     V50 ThinQ    5            옥션  mint****  19.05.23.
# 16   164       LM-V500     V50 ThinQ    5           G마켓  alsw****  19.05.23.
# 17   164       LM-V500     V50 ThinQ    5           G마켓  lees****  19.05.29.
# 18   164       LM-V500     V50 ThinQ    2            옥션  bboo****  19.08.06.
# 19   164       LM-V500     V50 ThinQ    5         롯데홈쇼핑  lar*****  19.07.24.
# 20   164       LM-V500     V50 ThinQ    5                jhj*****  19.07.01.
# 21   164       LM-V500     V50 ThinQ    5          인터파크  c*o*****  21.03.09.
# 22   164       LM-V500     V50 ThinQ    3           G마켓  n*n*****  21.02.05.
# 23   164       LM-V500     V50 ThinQ    5            옥션  m*n*****  21.02.16.
# 24   164       LM-V500     V50 ThinQ    5            옥션  j*n*****  21.02.28.
# 25   164       LM-V500     V50 ThinQ    5            옥션  r*d*****  21.03.07.
# 26   164       LM-V500     V50 ThinQ    5          인터파크  n*k*****  21.02.25.
# 27   164       LM-V500     V50 ThinQ    5            옥션  k*t*****  21.03.16.
# 28   164       LM-V500     V50 ThinQ    5           G마켓  r*a*****  21.03.12.
# 29   164       LM-V500     V50 ThinQ    5            옥션  n*v*****  21.03.04.
# 30   164       LM-V500     V50 ThinQ    5            옥션  i*v*****  21.03.08.
# 31   164       LM-V500     V50 ThinQ    5            옥션  j*9*****  21.03.07.
# 32   164       LM-V500     V50 ThinQ    5            옥션  e*9*****  21.03.07.
# 33   164       LM-V500     V50 ThinQ    4            옥션  e*e*****  21.02.08.
# 34   164       LM-V500     V50 ThinQ    5           G마켓  6*6*****  21.02.22.
# 35   164       LM-V500     V50 ThinQ    5            옥션  h*o*****  21.02.08.
# 36   164       LM-V500     V50 ThinQ    5           G마켓  21de****  19.09.11.
# 37   164       LM-V500     V50 ThinQ    4            옥션  t*i*****  20.03.02.
# 38   164       LM-V500     V50 ThinQ    5          인터파크  f*x*****  19.10.08.
# 39   164       LM-V500     V50 ThinQ    4          인터파크  d*d*****  20.01.16.
# 40   164       LM-V500     V50 ThinQ    5            옥션  h0w2****  19.09.25.
# 41   164       LM-V500     V50 ThinQ    5         SSG닷컴  st******  19.11.13.
# 42   164       LM-V500     V50 ThinQ    5         SSG닷컴  ss******  19.10.13.
# 43   164       LM-V500     V50 ThinQ    5         SSG닷컴  hu******  19.05.24.
# 44   164       LM-V500     V50 ThinQ    3       하이마트쇼핑몰  b*k*****  20.06.27.
# 45   164       LM-V500     V50 ThinQ    5          인터파크  0*m*****  19.11.10.
# 46   164       LM-V500     V50 ThinQ    4       하이마트쇼핑몰  m*k*****  19.05.21.
# 47   164       LM-V500     V50 ThinQ    5          11번가  ha******  19.05.27.
# 48   164       LM-V500     V50 ThinQ    5          11번가  sb******  19.05.19.
# 49   164       LM-V500     V50 ThinQ    5          11번가  ji******  19.05.14.
# 50   164       LM-V500     V50 ThinQ    5           폰이요  lulu****  21.03.12.
# 51   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  z*r*****  20.05.22.
# 52   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  m*l*****  20.08.25.
# 53   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  f*e*****  20.05.19.
# 54   164       LM-V500     V50 ThinQ    3       하이마트쇼핑몰  b*k*****  20.06.27.
# 55   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  f*e*****  20.06.12.
# 56   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  m*n*****  20.05.28.
# 57   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  z*r*****  20.05.22.
# 58   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  f*e*****  20.05.19.
# 59   164       LM-V500     V50 ThinQ    4       하이마트쇼핑몰  t*w*****  20.04.18.
# 60   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  l*n*****  20.04.14.
# 61   164       LM-V500     V50 ThinQ    5           컴퓨존  aoiy****  19.12.14.
# 62   164       LM-V500     V50 ThinQ    5          인터파크  l*e*****  19.10.18.
# 63   164       LM-V500     V50 ThinQ    5       하이마트쇼핑몰  s*b*****  19.06.21.
# 1    165       LM-V510    V50s ThinQ    5          인터파크  c*o*****  21.03.09.
# 2    165       LM-V510    V50s ThinQ    3           G마켓  n*n*****  21.02.05.
# 3    165       LM-V510    V50s ThinQ    5            옥션  m*n*****  21.02.16.
# 4    165       LM-V510    V50s ThinQ    5            옥션  j*n*****  21.02.28.
# 5    165       LM-V510    V50s ThinQ    5            옥션  r*d*****  21.03.07.
# 6    165       LM-V510    V50s ThinQ    5          인터파크  n*k*****  21.02.25.
# 7    165       LM-V510    V50s ThinQ    5            옥션  k*t*****  21.03.16.
# 8    165       LM-V510    V50s ThinQ    5           G마켓  r*a*****  21.03.12.
# 9    165       LM-V510    V50s ThinQ    5            옥션  n*v*****  21.03.04.
# 10   165       LM-V510    V50s ThinQ    5            옥션  i*v*****  21.03.08.
# 11   165       LM-V510    V50s ThinQ    5            옥션  j*9*****  21.03.07.
# 12   165       LM-V510    V50s ThinQ    5            옥션  e*9*****  21.03.07.
# 13   165       LM-V510    V50s ThinQ    4            옥션  e*e*****  21.02.08.
# 14   165       LM-V510    V50s ThinQ    5           G마켓  6*6*****  21.02.22.
# 15   165       LM-V510    V50s ThinQ    5            옥션  h*o*****  21.02.08.
# 16   165       LM-V510    V50s ThinQ    5       하이마트쇼핑몰  c*w*****  19.10.14.
# 17   165       LM-V510    V50s ThinQ    4           폰구오  chal****  20.10.24.
# 18   165       LM-V510    V50s ThinQ    5       하이마트쇼핑몰  s*g*****  20.01.14.
# 19   165       LM-V510    V50s ThinQ    4       하이마트쇼핑몰  a*r*****  19.10.13.
# 20   165       LM-V510    V50s ThinQ    3       하이마트쇼핑몰  m*m*****  20.01.15.
# 21   165       LM-V510    V50s ThinQ    1       하이마트쇼핑몰  tk******  19.12.02.
# 22   165       LM-V510    V50s ThinQ    5            옥션  je******  19.10.14.
# 23   165       LM-V510    V50s ThinQ    4       하이마트쇼핑몰  a*r*****  19.10.13.
# 24   165       LM-V510    V50s ThinQ    5            옥션  breg****  19.11.05.
# 25   165       LM-V510    V50s ThinQ    4           폰구오  auya****  20.10.28.
# 26   165       LM-V510    V50s ThinQ    5           폰구오  4734****  20.10.29.
# 27   165       LM-V510    V50s ThinQ    5       하이마트쇼핑몰  l*g*****  20.02.01.
# 28   165       LM-V510    V50s ThinQ    4           폰이요  mys4****  20.09.18.
# 29   165       LM-V510    V50s ThinQ    5            옥션  dbho****  19.12.03.
# 30   165       LM-V510    V50s ThinQ    5            옥션  dbho****  19.12.03.
# 31   165       LM-V510    V50s ThinQ    5           폰이요  turv****  20.11.09.
# 32   165       LM-V510    V50s ThinQ    5           폰이요  grid****  20.11.08.
# 33   165       LM-V510    V50s ThinQ    5           폰구오  eire****  20.07.06.
# 34   165       LM-V510    V50s ThinQ    5           폰이요  angi****  20.10.18.
# 35   165       LM-V510    V50s ThinQ    3           폰이요  gw00****  20.10.06.
# 1    166       LM-V409     V40 ThinQ    5           위메프  tur*****  19.11.29.
# 2    166       LM-V409     V40 ThinQ    5          인터파크  blac****  19.07.07.
# 3    166       LM-V409     V40 ThinQ    5           위메프  mol*****  19.12.08.
# 4    166       LM-V409     V40 ThinQ    5          인터파크  jaln****  19.08.05.
# 5    166       LM-V409     V40 ThinQ    5          인터파크  dlck****  19.06.30.
# 6    166       LM-V409     V40 ThinQ    5            옥션  jma*****  19.08.07.
# 7    166       LM-V409     V40 ThinQ    4          인터파크  thwl****  19.07.05.
# 8    166       LM-V409     V40 ThinQ    5           위메프  nam*****  19.12.05.
# 9    166       LM-V409     V40 ThinQ    5            옥션  d*3*****  20.01.31.
# 10   166       LM-V409     V40 ThinQ    5           위메프  uki*****  19.12.04.
# 11   166       LM-V409     V40 ThinQ    5           위메프  blu*****  19.11.21.
# 12   166       LM-V409     V40 ThinQ    5           G마켓  q*r*****  20.01.09.
# 13   166       LM-V409     V40 ThinQ    4            옥션  m*n*****  19.12.31.
# 14   166       LM-V409     V40 ThinQ    5           G마켓  love****  19.08.30.
# 15   166       LM-V409     V40 ThinQ    5            옥션  k763****  19.07.03.
# 16   166       LM-V409     V40 ThinQ    5          인터파크  p*i*****  19.12.10.
# 17   166       LM-V409     V40 ThinQ    5           위메프  ssi*****  19.11.27.
# 18   166       LM-V409     V40 ThinQ    5          인터파크  h*r*****  19.11.05.
# 19   166       LM-V409     V40 ThinQ    5       하이마트쇼핑몰  g*m*****  19.10.17.
# 20   166       LM-V409     V40 ThinQ    5           위메프  jbg*****  19.09.26.
# 21   166       LM-V409     V40 ThinQ    4                est*****  19.10.08.
# 22   166       LM-V409     V40 ThinQ    5                ykr*****  19.10.01.
# 23   166       LM-V409     V40 ThinQ    2                aym*****  19.10.19.
# 24   166       LM-V409     V40 ThinQ    5                whg*****  19.10.09.
# 25   166       LM-V409     V40 ThinQ    5                gri*****  19.10.09.
# 26   166       LM-V409     V40 ThinQ    5                wow*****  19.05.16.
# 27   166       LM-V409     V40 ThinQ    5          인터파크  grea****  19.03.21.
# 28   166       LM-V409     V40 ThinQ    5            옥션  paul****  19.11.08.
# 29   166       LM-V409     V40 ThinQ    5                cry*****  19.10.22.
# 30   166       LM-V409     V40 ThinQ    5                ssa*****  19.10.09.
# 31   166       LM-V409     V40 ThinQ    5          인터파크  r*v*****  19.09.21.
# 32   166       LM-V409     V40 ThinQ    5         롯데홈쇼핑  koj*****  19.12.06.
# 33   166       LM-V409     V40 ThinQ    5          인터파크  dara****  19.07.22.
# 34   166       LM-V409     V40 ThinQ    5          인터파크  d*t*****  19.10.16.
# 35   166       LM-V409     V40 ThinQ    5          인터파크  l*i*****  19.11.07.
# 36   166       LM-V409     V40 ThinQ    5            옥션  myci****  19.11.06.
# 37   166       LM-V409     V40 ThinQ    4          인터파크  k*s*****  19.10.30.
# 38   166       LM-V409     V40 ThinQ    4                don*****  19.10.13.
# 39   166       LM-V409     V40 ThinQ    4          인터파크  f*m*****  19.09.27.
# 40   166       LM-V409     V40 ThinQ    5          인터파크  p*k*****  19.10.01.
# 41   166       LM-V409     V40 ThinQ    5           G마켓  csk6****  19.08.30.
# 42   166       LM-V409     V40 ThinQ    5            옥션  hn******  19.08.24.
# 43   166       LM-V409     V40 ThinQ    5           G마켓  abso****  19.08.23.
# 44   166       LM-V409     V40 ThinQ    5            옥션  97dy****  19.08.29.
# 45   166       LM-V409     V40 ThinQ    5            옥션  jaeh****  19.08.27.
# 1    167       LM-V350           V35    4          인터파크  mi******  19.02.21.
# 2    167       LM-V350           V35    5                mot*****  19.05.14.
# 3    167       LM-V350           V35    5          인터파크  moho****  17.06.05.
# 4    167       LM-V350           V35    5          인터파크  lubi****  19.02.09.
# 5    167       LM-V350           V35    5          인터파크  sung****  19.01.09.
# 6    167       LM-V350           V35    5          인터파크  a8******  18.10.11.
# 7    167       LM-V350           V35    5          인터파크  unk*****  19.01.14.
# 8    167       LM-V350           V35    5          인터파크  jaso****  18.12.31.
# 9    167       LM-V350           V35    5          인터파크  ddp*****  18.12.12.
# 10   167       LM-V350           V35    5          인터파크  ddp*****  18.12.27.
# 11   167       LM-V350           V35    5          인터파크  lcw*****  18.11.21.
# 12   167       LM-V350           V35    5          인터파크  doq*****  18.11.17.
# 13   167       LM-V350           V35    5          인터파크  pms*****  18.11.03.
# 14   167       LM-V350           V35    5          인터파크  book****  18.11.03.
# 15   167       LM-V350           V35    5          인터파크  wjdd****  18.11.01.
# 16   167       LM-V350           V35    5          인터파크  nas*****  18.10.31.
# 17   167       LM-V350           V35    5          인터파크  rohd****  18.10.24.
# 18   167       LM-V350           V35    5          인터파크  khyu****  18.09.28.
# 19   167       LM-V350           V35    5          인터파크  saso****  18.10.08.
# 20   167       LM-V350           V35    5          인터파크  wltn****  17.11.30.
# 21   167       LM-V350           V35    5          인터파크  ssu*****  17.06.28.
# 1    169      LGM-V300           V30    5          인터파크  wlwl****  18.11.02.
# 2    169      LGM-V300           V30    5          인터파크  cdpj****  18.08.02.
# 3    169      LGM-V300           V30    5          인터파크  khi*****  18.09.24.
# 4    169      LGM-V300           V30    4          인터파크  sim*****  17.11.15.
# 5    169      LGM-V300           V30    3          인터파크  jui*****  16.12.22.
# 6    169      LGM-V300           V30    5          인터파크  cam*****  16.11.28.
# 7    169      LGM-V300           V30    5          인터파크  kkd*****  17.01.09.
# 8    169      LGM-V300           V30    4          인터파크  qudw****  16.12.14.
# 9    169      LGM-V300           V30    4          인터파크  sim*****  18.12.09.
# 10   169      LGM-V300           V30    5          인터파크  sim*****  18.11.22.
# 11   169      LGM-V300           V30    5          인터파크  lsh*****  18.12.13.
# 12   169      LGM-V300           V30    5          인터파크  ls******  18.10.06.
# 13   169      LGM-V300           V30    5          인터파크  hann****  18.11.27.
# 14   169      LGM-V300           V30    5          인터파크  happ****  18.11.27.
# 15   169      LGM-V300           V30    5          인터파크  nex*****  18.11.29.
# 16   169      LGM-V300           V30    5          인터파크  iun*****  18.12.07.
# 17   169      LGM-V300           V30    5          인터파크  jji*****  18.11.28.
# 18   169      LGM-V300           V30    5          인터파크  jji*****  18.11.28.
# 19   169      LGM-V300           V30    5          인터파크  goju****  18.11.16.
# 20   169      LGM-V300           V30    5          인터파크  aisi****  18.11.18.
# 21   169      LGM-V300           V30    5          인터파크  vs5*****  18.12.27.
# 22   169      LGM-V300           V30    5          인터파크  upo*****  18.09.21.
# 23   169      LGM-V300           V30    5         롯데홈쇼핑  ops*****  19.06.18.
# 24   169      LGM-V300           V30    5            옥션  tast****  19.06.05.
# 25   169      LGM-V300           V30    5          인터파크  are*****  18.11.17.
# 26   169      LGM-V300           V30    5          인터파크  youf****  18.10.07.
# 27   169      LGM-V300           V30    5          인터파크  youf****  18.10.07.
# 28   169      LGM-V300           V30    5          인터파크  leeh****  19.01.08.
# 29   169      LGM-V300           V30    5          인터파크  made****  18.12.30.
# 30   169      LGM-V300           V30    5          인터파크  thdw****  18.12.19.
# 31   169      LGM-V300           V30    5          인터파크  myrr****  18.12.14.
# 32   169      LGM-V300           V30    5          인터파크  sunu****  18.11.08.
# 33   169      LGM-V300           V30    5          인터파크  dae*****  18.09.29.
# 34   169      LGM-V300           V30    5          인터파크  seow****  18.10.10.
# 35   169      LGM-V300           V30    5          인터파크  spee****  18.10.08.
# 36   169      LGM-V300           V30    5          인터파크  play****  18.10.01.
# 37   169      LGM-V300           V30    5          인터파크  tkdr****  18.09.22.
# 38   169      LGM-V300           V30    5          인터파크  nkh*****  18.09.09.
# 39   169      LGM-V300           V30    5          인터파크  sk96****  18.09.13.
# 40   169      LGM-V300           V30    5            옥션  hyun****  17.03.18.
# 41   169      LGM-V300           V30    5       하이마트쇼핑몰  ro******  17.09.22.
# 42   169      LGM-V300           V30    5         롯데홈쇼핑  fir*****  18.01.05.
# 1    170       LG-F800           V20    3          인터파크  blue****  16.11.20.
# 2    170       LG-F800           V20    5           G마켓  shan****  17.05.02.
# 3    170       LG-F800           V20    5          인터파크  haf*****  17.04.19.
# 4    170       LG-F800           V20    5          11번가  mj******  17.03.03.
# 5    170       LG-F800           V20    5          인터파크  ma******  17.05.04.
# 6    170       LG-F800           V20    2          인터파크  an******  17.01.23.
# 7    170       LG-F800           V20    4          인터파크  dani****  17.01.17.
# 3    173       LM-X410            X4    4            옥션  j*m*****  20.02.14.
# 4    173       LM-X410            X4    2          11번가  ba******  19.06.18.
# 5    173       LM-X410            X4    5          인터파크  mash****  19.07.13.
# 6    173       LM-X410            X4    5       하이마트쇼핑몰  i*i*****  20.03.10.
# 7    173       LM-X410            X4    5          인터파크  mash****  19.07.13.
# 8    173       LM-X410            X4    5           G마켓  chr3****  19.05.29.
# 9    173       LM-X410            X4    5          11번가  ss******  19.07.04.
# 10   173       LM-X410            X4    5          11번가  jh******  19.09.12.
# 11   173       LM-X410            X4    5          인터파크  neo*****  19.08.03.
# 12   173       LM-X410            X4    5          인터파크  hime****  19.07.16.
# 13   173       LM-X410            X4    1          11번가  by******  19.09.24.
# 14   173       LM-X410            X4    4          인터파크  ma******  19.07.08.
# 15   173       LM-X410            X4    5          인터파크  rund****  19.07.11.
# 16   173       LM-X410            X4    5            옥션  kos0****  19.05.02.
# 17   173       LM-X410            X4    5            옥션  dubu****  19.05.02.
# 18   173       LM-X410            X4    4           위메프  che*****  19.06.18.
# 19   173       LM-X410            X4    3           G마켓  pdu*****  19.05.16.
# 20   173       LM-X410            X4    5          11번가  ch******  19.05.31.
# 1    175       LM-X625       X6 2019    5       아이비에스N샵  jeer****  20.07.21.
# 2    175       LM-X625       X6 2019    4           G마켓  c*a*****  20.06.25.
# 3    175       LM-X625       X6 2019    3          11번가  ge******  19.09.03.
# 4    175       LM-X625       X6 2019    4          11번가  im******  19.08.06.
# 5    175       LM-X625       X6 2019    5          11번가  if******  19.07.10.
# 6    175       LM-X625       X6 2019    5          11번가  rr******  19.09.03.
# 7    175       LM-X625       X6 2019    5          11번가  id******  19.07.04.
# 8    175       LM-X625       X6 2019    4       아이비에스N샵  lmsl****  20.04.09.
# 9    175       LM-X625       X6 2019    5          11번가  gy******  19.09.22.
# 10   175       LM-X625       X6 2019    4          11번가  jj******  19.10.02.
# 11   175       LM-X625       X6 2019    3          11번가  cj******  19.06.26.
# 12   175       LM-X625       X6 2019    3          11번가  so******  19.09.25.
# 13   175       LM-X625       X6 2019    3          11번가  mo******  19.07.10.
# 14   175       LM-X625       X6 2019    5          11번가  ks******  19.11.14.
# 15   175       LM-X625       X6 2019    5          11번가  ge******  19.07.06.
# 16   175       LM-X625       X6 2019    4          11번가  my******  19.07.09.
# 17   175       LM-X625       X6 2019    4          11번가  wj******  19.09.05.
# 18   175       LM-X625       X6 2019    5          11번가  sh******  19.07.10.
# 19   175       LM-X625       X6 2019    5           위메프  nss*****  19.07.01.
# 20   175       LM-X625       X6 2019    5          11번가  tp******  19.07.30.
# 1    176       LM-X420       X4 2019    3            옥션  shwa****  19.10.02.
# 2    176       LM-X420       X4 2019    4           G마켓  shp5****  19.06.11.
# 3    176       LM-X420       X4 2019    4            옥션  j*m*****  20.02.14.
# 4    176       LM-X420       X4 2019    2          11번가  ba******  19.06.18.
# 5    176       LM-X420       X4 2019    5          인터파크  mash****  19.07.13.
# 6    176       LM-X420       X4 2019    5       하이마트쇼핑몰  i*i*****  20.03.10.
# 7    176       LM-X420       X4 2019    5          인터파크  mash****  19.07.13.
# 8    176       LM-X420       X4 2019    5           G마켓  chr3****  19.05.29.
# 9    176       LM-X420       X4 2019    5          11번가  ss******  19.07.04.
# 10   176       LM-X420       X4 2019    5          11번가  jh******  19.09.12.
# 11   176       LM-X420       X4 2019    5          인터파크  neo*****  19.08.03.
# 12   176       LM-X420       X4 2019    5          인터파크  hime****  19.07.16.
# 13   176       LM-X420       X4 2019    1          11번가  by******  19.09.24.
# 14   176       LM-X420       X4 2019    4          인터파크  ma******  19.07.08.
# 15   176       LM-X420       X4 2019    5          인터파크  rund****  19.07.11.
# 16   176       LM-X420       X4 2019    5            옥션  kos0****  19.05.02.
# 17   176       LM-X420       X4 2019    5            옥션  dubu****  19.05.02.
# 18   176       LM-X420       X4 2019    4           위메프  che*****  19.06.18.
# 19   176       LM-X420       X4 2019    3           G마켓  pdu*****  19.05.16.
# 20   176       LM-X420       X4 2019    5          11번가  ch******  19.05.31.
# 1    181      LGM-K121          X400    5            옥션  limn****  17.03.03.
# 2    181      LGM-K121          X400    5         롯데홈쇼핑  dor*****  17.05.11.
# 3    181      LGM-K121          X400    5            옥션  haph****  17.05.29.
# 1    182      LGM-K120          X300    5         롯데홈쇼핑  sbh*****  17.05.23.
# 2    182      LGM-K120          X300    4          인터파크  moo*****  17.02.13.
# 3    182      LGM-K120          X300    5          인터파크  113*****  17.02.11.
# 1    184       LG-F770            X5    5                bea*****  19.01.07.
# 2    184       LG-F770            X5    5          인터파크  s*n*****  19.08.28.
# 3    184       LG-F770            X5    5          11번가  ky******  18.07.12.
# 4    184       LG-F770            X5    5          인터파크  cade****  16.08.05.
# 5    184       LG-F770            X5    5          인터파크  min*****  16.08.26.
# 1    187       LG-F650          X스크린    3          11번가  pu******  16.09.08.
# 1    188       LG-H791        넥서스 5x    5            옥션  auu*****  15.11.16.
# 1    191       LG-F480        와인 스마트    5            옥션  d*v*****  20.04.14.
# 2    191       LG-F480        와인 스마트    5           G마켓  eum3****  18.06.27.
# 3    191       LG-F480        와인 스마트    5           G마켓  k*9*****  21.02.08.
# 4    191       LG-F480        와인 스마트    4            옥션  chak****  19.12.10.
# 5    191       LG-F480        와인 스마트    5            옥션  tjsw****  19.03.27.
# 6    191       LG-F480        와인 스마트    5           G마켓  s74*****  18.08.03.
# 7    191       LG-F480        와인 스마트    5           G마켓  cs95****  18.06.14.
# 8    191       LG-F480        와인 스마트    4           G마켓  hurm****  18.05.08.
# 9    191       LG-F480        와인 스마트    4           G마켓  y2k*****  18.03.28.
# 10   191       LG-F480        와인 스마트    5            옥션  boo0****  17.10.11.
# 1    192       LG-T480     와인 스마트 3G    5            옥션  d*v*****  20.04.14.
# 2    192       LG-T480     와인 스마트 3G    5           G마켓  eum3****  18.06.27.
# 3    192       LG-T480     와인 스마트 3G    5           G마켓  k*9*****  21.02.08.
# 4    192       LG-T480     와인 스마트 3G    4            옥션  chak****  19.12.10.
# 5    192       LG-T480     와인 스마트 3G    5            옥션  tjsw****  19.03.27.
# 6    192       LG-T480     와인 스마트 3G    5           G마켓  s74*****  18.08.03.
# 7    192       LG-T480     와인 스마트 3G    5           G마켓  cs95****  18.06.14.
# 8    192       LG-T480     와인 스마트 3G    4           G마켓  hurm****  18.05.08.
# 9    192       LG-T480     와인 스마트 3G    4           G마켓  y2k*****  18.03.28.
# 10   192       LG-T480     와인 스마트 3G    5            옥션  boo0****  17.10.11.
# 1    193       LM-Y110          LG폴더    5          인터파크  imbu****  19.03.27.
# 2    193       LM-Y110          LG폴더    5          인터파크  ls******  18.10.04.
# 3    193       LM-Y110          LG폴더    5          인터파크  shin****  18.02.13.
# 4    193       LM-Y110          LG폴더    5          인터파크  sent****  18.01.30.
# 5    193       LM-Y110          LG폴더    4         롯데홈쇼핑  rox*****  19.01.02.
# 1    194      LGM-X100         스마트폴더    5          인터파크  imbu****  19.03.27.
# 2    194      LGM-X100         스마트폴더    5          인터파크  ls******  18.10.04.
# 3    194      LGM-X100         스마트폴더    5          인터파크  shin****  18.02.13.
# 4    194      LGM-X100         스마트폴더    5          인터파크  sent****  18.01.30.
# 1    195       SM-F907        갤럭시 폴드    4          인터파크  y*c*****  20.11.12.
# 2    195       SM-F907        갤럭시 폴드    5          인터파크  d*2*****  21.01.08.
# 3    195       SM-F907        갤럭시 폴드    5          아이씨이  fa5*****  20.03.18.
# 4    195       SM-F907        갤럭시 폴드    5          아이씨이  mecr****  20.03.19.
# 5    195       SM-F907        갤럭시 폴드    5          아이씨이  baey****  20.03.12.
# 6    195       SM-F907        갤럭시 폴드    5       하이마트쇼핑몰  l*j*****  20.02.24.
# 7    195       SM-F907        갤럭시 폴드    5          아이씨이  mecr****  20.02.03.
# 8    195       SM-F907        갤럭시 폴드    5           G마켓  n*h*****  20.12.29.
# 9    195       SM-F907        갤럭시 폴드    5          아이씨이  jcli****  20.04.02.
# 10   195       SM-F907        갤럭시 폴드    5          민앤슈가  zxck****  20.01.29.
# 11   195       SM-F907        갤럭시 폴드    4       하이마트쇼핑몰  S*B*****  19.10.02.
# 12   195       SM-F907        갤럭시 폴드    5       하이마트쇼핑몰  x*i*****  19.10.22.
# 13   195       SM-F907        갤럭시 폴드    5       하이마트쇼핑몰  z*a*****  19.10.11.
# 14   195       SM-F907        갤럭시 폴드    4       하이마트쇼핑몰  g*b*****  19.10.02.
# 15   195       SM-F907        갤럭시 폴드    5       하이마트쇼핑몰  l*k*****  19.10.06.
# 16   195       SM-F907        갤럭시 폴드    4       하이마트쇼핑몰  S*B*****  19.10.02.
# 17   195       SM-F907        갤럭시 폴드    1          인터파크  w*o*****  20.12.19.
# 18   195       SM-F907        갤럭시 폴드    5          아이씨이  chan****  21.03.13.
# 19   195       SM-F907        갤럭시 폴드    5          아이씨이  web_****  20.02.06.
# 20   195       SM-F907        갤럭시 폴드    5          아이씨이  a_d_****  20.12.11.
# 21   195       SM-F907        갤럭시 폴드    5        DSmall  anwl****  20.11.16.
# 22   195       SM-F907        갤럭시 폴드    5           위메프  925*****  20.11.15.
# 23   195       SM-F907        갤럭시 폴드    4           위메프  dkd*****  21.01.08.
# 24   195       SM-F907        갤럭시 폴드    5          아이씨이  kiny****  20.11.28.
# 25   195       SM-F907        갤럭시 폴드    3            옥션  s*n*****  20.12.16.
# 26   195       SM-F907        갤럭시 폴드    5       하이마트쇼핑몰
# 13  용량이 부족하단 문구땜시..전원도 여러번 꺼지고  새로 장만했어요..쿠폰에 카드할인...
# 14  아버지 폰 바꿔드리려고 알아보다가 할인을 덜 받더라도 개통등이 편한게 좋겠다 싶어 ...
# 15  배송은 빨랐고 경비실에 맞겨 주셔서 안전하게 받았습니다.장점은 가격이고요. 부모님 ...
# 16  자급제 폰 정말 좋아요가개통 폰은 말만 미사용이지 이미 뜯은 것은 중고나 다름 없는...
# 17  진짜 총알배송이네요 낮12시10분전에 결제했는데 30분도안되서 배송업체로 넘어가더니...
# 18  한달 안되어서 사용중 불량으로 환불 받았습니다.. 처음부터 지문인식이 안됐었는데 필...
# 19  1~2주 걸린다고 하셨는데 이틀만에 받았어요. 너무 만족스러워요.아침부터 기사님 3...
# 20  어머니가 비싼 휴대폰은 부담스러워서 하셔서 보급형 휴대폰으로 선택했는데 엄청 만족스...
# 21  지인이 4~5 년된 기존폰 배터리가 간당간당해서 공폰으로 주문해 주었는데 세팅해보니...
# 1   통신사 약정도 끝났고 전에 쓰던 아이폰이 덜덜거려 새로운 폰을 알아봤는데 s20 같...
# 2   스마트폰을 아이폰6를 4년 넘게 사용하다 삼성은 처음 써봅니다. 아이폰을 쓰다 갤럭...
# 3   하루만에 도착. 자급제폰은 처음이라서 조마조마했네요. 초기 설정?도 어렵지 않았고,...
# 4   가격은 정가 그대로 주고 샀지만 이벤트로 포인트적립 진행하니 만족해요! 출고는 주문...
# 5   6년 가까이 쓰던 폰(갤S6)의 배터리 성능 저하와 용량 부족 때문에 아주 좋은 폰...
# 6   예비중학생 딸 주려고 구매했어요~ 폰 바꿔주려했더니 5g 의무가입에 가격이 너무 사...
# 7   배송 아주 빠드네요.. 제품도 아주 만족합니다. 액정 지문인식이 되니 딸이 아주 좋...
# 8   처음으로  선물하기사용하여  아들폰을구입했습니다ㆍ자급제 새폰으로  좋은조건으로 구입...
# 9   엄마 핸드폰 바꿔드릴려고 원래는 해외에서 주문하려다가 불량이 꽤 있는것 같아서 돈 ...
# 10  검은색대신 흰색구매하였으나 뒤판은 단일 흰색이 아니어서 나름 좋음. 택배도 일찍오고...
# 11  어머니 폰 바꿔드릴려구 구매했습니다. 어머니 예전폰이 s9인데요. 확실히 좋타라는 ...
# 12  금요일에 받아서 사용하고 있는데.. 저만 그런가요..? 중간 중간 터치가 먹통일 때...
# 13  어머니 선물용으로 구매하였어요! 배송도 정말 빨랐고 다 만족합니다! 주말에 선물 드...
# 14  아빠 핸드폰이 고장나서 새로 사드렸는데 좋아하시네요자급제폰 처음 구입해보는데 기존에...
# 15  처음에 배터리가 너무 빨리 달아서 불량아닌가 의심을 많이했지만 지금 그럭저럭 괜찮아...
# 16  다음날 바로 발송해주셨는데 택배파업과 시기가 맞물렸는지 허브에 갇혀서 좀 늦었어요ㅠ...
# 17  화면도크고 이뻐요 휴대폰 굳이 백만원돈으로사야할이유를 못느낄만큼 기능도많고 삼성페이...
# 18  a30, a31, a51 전부 사용해보니 기능상으로는 a30 이 가장 아래이기는 한...
# 19  완전 최고.   배송 품질 가격 삼박자 모두 만족합니다. 최고의 판매자입니다. 배송...
# 8   후기가 하나도 없어서 고민하다가 이거 파는 회사평이 좋길래 물어보고 샀습니다. 직원...
# 9   제품상태는 ss급입니다. 다만 전 후면면에 붙어 있던 필름은 제거되고 옵니다. 어짜...
# 10  제품은 좋습니다 오랜만에 휴대폰 바꾸니 확실히 빠르네요. S펜을 업무할 때 워낙 잘...
# 11  휴대폰 카메라에 안쪽에 티가 하나 붙어있었네요 휴대폰 외관에는 스티커 제거 되고케이...
# 12                                     배송 빠르고 새제품 이네여
# 13               배송도 안전하고 빠르게 왔어요. 자급제 신품 확인 이상없고 좋아요
# 14  검수해서 잘 보내주셨는데 뒤쪽에 3군데 찍힘이 있네요. 좀 아쉽지만 좀 저렴하게 구...
# 15                             가산점 에서 바로 방문수령했어요 좋습니다
# 16             액정 필름도 붙혀있고여분 필름 케이스도 감사합니다오래 썼으면 좋겠네요
# 17                              별 이상없이 빠른배송으로 잘받았습니다.
# 18  만족합니다. 원래부터 자급제폰으로구입하려 했는데 저렴하게 구매할 수 있어서  만족합니다,
# 19  뽑기를 잘못뽑았는지 사용 일주일 후 부터 휴대폰 껏다켜졌다  반복으로 메인보드  교체받음
# 20  최대 할인인 줄 알았는데 며칠사이 할인률이 더 높아져서 ㅠㅜ... 그래도 제품은 아...
# 21  쓰던폰이 상태가 안좋아지고 있던중 노트를 써보고 싶어서 알아보고 있었는데 때마침 라...
# 22  배송은 예상날짜보다 빨리 왔네요받자 마자 미리 준비한 카메라 보호필름과 보호커버를 ...
# 23  cj택배대란으로 걱정했는데 택배 이틀만에 왔구요ㅎㅎ 택배수취 확인하자마자 회사에서 ...
# 24  부모님 폰인데 네이버에서 8월 12일에 갤놋20 이벤트해서 주문했는데 물량이 밀려서...
# 25  발송예정일보다 일찍 와서 놀랬어요!무사히 도착했구 특이한 이상없어 바로 데이터 옮기...
# 26  역시 노트20울트라 손에 속 감기네요맘에 드네요 대용량에 최신카메라 까지 터치가 죽...
# 27  오랜만에 바꾸니 좋네요. 노트8도 좋은 폰이지만 배터리가..너무 빨리 닳아서 바꿨어...
# 28  하루만에 배송 받았구요.kt대리점 방문해서 일반기변 신청할거라아직 유심은 꽂지 않았...
# 29  만족합니다. 아내가 매우 좋아합니다. 다행이고.. 노트4를 쓰던 아내에게 미안함이 ...
# 30  블랙 너무 멋져요. 갤노트 2 -> 5 -> 8 -> 20 으로 4대째 사용중입니다...
# 31  믿고쓰는 갤럭시 프리미엄 라인이라서 딘딘님 생방시작하자마자 구매했습니다. 배송도 2...
# 32  배송엄청빠르고  완전 좋네요.. 여기 상담해주는 여직원분이 엄청 친절하세요~  미개...
# 33  결제 후 다음 날 택배를 받았습니다.에어켑으로 이중, 삼중 꼼꼼하게 포장이 잘 되어...
# 34  미스틱브론즈 주문했는대 화이트로 수정되어서 받았읍니다.화이트라 깔끔합니다. 포장도 ...
# 35  미개봉씰을 누가 손톱으로 뜯으려고 들어내다가 도저희 안되서 반품한 제품을 보낸것같습...
# 36  노트20 울트라인 인기 때문인지 몰라도 배송이 좀 지연 되었지만, 친절한 지연 안내...
# 37  자급제폰 구매하실분 연락주세요ㅠ업무용으로 투넘버 사용하는데 자급제폰을 사용하면 투넘...
# 38         안깨지도록 포장을 정말 꼼꼼히 해주셨어요 ㅋㅋ 이쁘게 잘 사용하겠습니다 ㅋㅋ
# 39        생각보다 빠른배송, 그리고 구매 후 메세지로 사은품 안내도 너무 친절했습니다.
# 40       외형에는 육안으로 이상 없는것 같아요.렌즈도 잘나온것같구요 ㅎ색상도 예쁘네요~!
# 41                               웬만한 것대리점보다 해택이 정확하네요
# 42                            가격도 저렴하고 배송도 빠르고 좋앗습니다.
# 43    가족모두 노트20 울트라로 휴대폰을 바꿨는데 제가 제일 저렴하게 구매했어요~감사합니다
# 44                                      저렴하게 잘 구입 했네요
# 45              배송 바로 다음날 왔구요... 이것저것 할인받아 잘 구매했네요..,
# 46                               빠르게 배송왔고 개통도 잘 되었습니다
# 47                          빠른배송 감사합니다  설명도 친절하게해주셨어요
# 48                                       빠른 배송 감사합니다.
# 49   새  제품이니 써 봐야 정확한 리뷰를 올리겠지요. 써 보고 문제 있으면 리뷰 올릴게요.
# 1   쓰던폰이 상태가 안좋아지고 있던중 노트를 써보고 싶어서 알아보고 있었는데 때마침 라...
# 2   배송은 예상날짜보다 빨리 왔네요받자 마자 미리 준비한 카메라 보호필름과 보호커버를 ...
# 3   cj택배대란으로 걱정했는데 택배 이틀만에 왔구요ㅎㅎ 택배수취 확인하자마자 회사에서 ...
# 4   부모님 폰인데 네이버에서 8월 12일에 갤놋20 이벤트해서 주문했는데 물량이 밀려서...
# 5   발송예정일보다 일찍 와서 놀랬어요!무사히 도착했구 특이한 이상없어 바로 데이터 옮기...
# 6   역시 노트20울트라 손에 속 감기네요맘에 드네요 대용량에 최신카메라 까지 터치가 죽...
# 7   오랜만에 바꾸니 좋네요. 노트8도 좋은 폰이지만 배터리가..너무 빨리 닳아서 바꿨어...
# 8   하루만에 배송 받았구요.kt대리점 방문해서 일반기변 신청할거라아직 유심은 꽂지 않았...
# 9   만족합니다. 아내가 매우 좋아합니다. 다행이고.. 노트4를 쓰던 아내에게 미안함이 ...
# 10  블랙 너무 멋져요. 갤노트 2 -> 5 -> 8 -> 20 으로 4대째 사용중입니다...
# 11  믿고쓰는 갤럭시 프리미엄 라인이라서 딘딘님 생방시작하자마자 구매했습니다. 배송도 2...
# 12  배송엄청빠르고  완전 좋네요.. 여기 상담해주는 여직원분이 엄청 친절하세요~  미개...
# 13  결제 후 다음 날 택배를 받았습니다.에어켑으로 이중, 삼중 꼼꼼하게 포장이 잘 되어...
# 14  미스틱브론즈 주문했는대 화이트로 수정되어서 받았읍니다.화이트라 깔끔합니다. 포장도 ...
# 15  미개봉씰을 누가 손톱으로 뜯으려고 들어내다가 도저희 안되서 반품한 제품을 보낸것같습...
# 16  노트20 울트라인 인기 때문인지 몰라도 배송이 좀 지연 되었지만, 친절한 지연 안내...
# 17  자급제폰 구매하실분 연락주세요ㅠ업무용으로 투넘버 사용하는데 자급제폰을 사용하면 투넘...
# 18         안깨지도록 포장을 정말 꼼꼼히 해주셨어요 ㅋㅋ 이쁘게 잘 사용하겠습니다 ㅋㅋ
# 19        생각보다 빠른배송, 그리고 구매 후 메세지로 사은품 안내도 너무 친절했습니다.
# 20       외형에는 육안으로 이상 없는것 같아요.렌즈도 잘나온것같구요 ㅎ색상도 예쁘네요~!
# 21                               웬만한 것대리점보다 해택이 정확하네요
# 22                            가격도 저렴하고 배송도 빠르고 좋앗습니다.
# 23    가족모두 노트20 울트라로 휴대폰을 바꿨는데 제가 제일 저렴하게 구매했어요~감사합니다
# 24                                      저렴하게 잘 구입 했네요
# 25              배송 바로 다음날 왔구요... 이것저것 할인받아 잘 구매했네요..,
# 26                               빠르게 배송왔고 개통도 잘 되었습니다
# 27                          빠른배송 감사합니다  설명도 친절하게해주셨어요
# 28                                       빠른 배송 감사합니다.
# 29   새  제품이니 써 봐야 정확한 리뷰를 올리겠지요. 써 보고 문제 있으면 리뷰 올릴게요.

# %%
crawl_data.to_csv('review_data1.csv.csv',encoding='utf-8-sig')

# %% [markdown]
# # 엑셀에서 pl_id 오름차순, text_len(추가후) 내림차순 정렬하고 난 후 => file.csv

# %%
#####################################################################################
######################### 크롤링 데이터 초기화 ######################################
#####################################################################################
my_dict = {
    "pl_id": "",                    #모델영문명
    "text1": "",
    "text2": "",
    "text3": ""
}

filtered_reivew = pd.DataFrame(my_dict,index=[0])
filtered_reivew_none = pd.DataFrame(my_dict,index=[0])
#######################################################################################
#######################################################################################
#######################################################################################

df_output = pd.read_csv('file.csv')
pl_ids = df_output['pl_id'].unique()
models = []
for pl_id in pl_ids:
    is_name = df_output['pl_id'] == pl_id
    model = df_output[is_name]
    my_dict = {
    "pl_id": pl_id,                 
    }
    
    print(len(model))
    if len(model) > 0:
        my_dict["text1"] = model.iloc[0]['text']
    if len(model) > 1:
        my_dict["text2"] = model.iloc[1]['text']
    if len(model) > 2:
        my_dict["text3"] = model.iloc[2]['text']
    
    filtered_reivew = filtered_reivew.append(pd.DataFrame(my_dict,index=[0]))
# Out:
# 89
# 67
# 60
# 80
# 44
# 72
# 77
# 76
# 43
# 86
# 22
# 62
# 70
# 10
# 68
# 8
# 20
# 21
# 20
# 42
# 17
# 15
# 20
# 3
# 25
# 22
# 29
# 45
# 14
# 26
# 44
# 100
# 55
# 14
# 57
# 100
# 10
# 8
# 8
# 2
# 4
# 8
# 23
# 1
# 77
# 80
# 88
# 81
# 89
# 74
# 80
# 39
# 81
# 54
# 42
# 82
# 100
# 85
# 13
# 13
# 36
# 33
# 100
# 85
# 37
# 32
# 25
# 7
# 71
# 12
# 1
# 56
# 16
# 92
# 12
# 6
# 20
# 45
# 86
# 32
# 20
# 20
# 10
# 10
# 1
# 10
# 7
# 11
# 4
# 13
# 10
# 27
# 1
# 8
# 8
# 8
# 4
# 1
# 2
# 63
# 35
# 45
# 21
# 42
# 31
# 16
# 3
# 20
# 20
# 20
# 3
# 3
# 5
# 1
# 1
# 10
# 10
# 5
# 4
# 48
# 6
# 52
# 65
# 55
# 28
# 23
# 20
# 20
# 21
# 21
# 20
# 49
# 29
# 20
# 22
# 1
# 35
# 35
# 35
# 35
# 4
# 13
# 100
# 20
# 20
# 15
# 16
# 12
# 3
# 20

# %%
filtered_reivew.to_csv('filtered_reivew.csv',encoding='utf-8-sig')
