# %% [markdown]
# # 1. 엑셀데이터 불러오기

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import numpy as np
import re
import os
from pyvirtualdisplay import Display
from selenium import webdriver
import time

df_input = pd.read_csv('../input_data_~0407 (version 1).csv')
df_input.iloc[0]
# Out:
# pl_id                                          1
# pl_maker                                   apple
# pl_model_code                              A2221
# pl_name                                    아이폰11
# pl_model_name                           iphone11
# Unnamed: 5                                   NaN
# 나무위키링크단품         https://namu.wiki/w/iPhone%2011
# Unnamed: 7                                   NaN
# Unnamed: 8                                   NaN
# Unnamed: 9                                   NaN
# Name: 0, dtype: object

# %% [markdown]
# # 2. 리뷰크롤링

# %%
import time
#####################################################################################
######################### 크롤링 데이터 초기화 ######################################
#####################################################################################
my_dict = {
    "pl_id": "",                      #스펙테이블 아이디
    "pl_model_code": "",              #모델코드
    "pl_name": "",                    #모델영문명
    
    "star": "",                       #별점
    "market": "",                     #구입처(ex 인터파크, 11번가)
    "write_id": "",                   #작성자(일부가림처리)
    "upload_day": "",                 #업로드날짜
    "title":"",                       #리뷰제목 
    "text": "",                        #리뷰내용 
    "Target":""                       #리뷰대상이 되는 상품!!(실제랑 다를 수 있으므로)
}

crawl_data = pd.DataFrame(my_dict,index=[0])
crawl_data_none = pd.DataFrame(my_dict,index=[0])
#######################################################################################
#######################################################################################
#######################################################################################

def search_by_category(df_input,crawl_data,index,option):
    url1 = 'https://search.11st.co.kr/Search.tmall?method=getCatalogPrdSearch&catalogYN=Y&kwd='
    driver.get(url1+df_input.iloc[index]['pl_name']+"#chkCtgrNo%%1059026%%휴대폰완납가입%%10$$$$")
    driver.implicitly_wait(3)
    
    
    #페이지에 있는 링크 다 긁어오기, 일단 스크롤기능 추가안해서 5개만 가져옴 => 5개 넘어가면 검색정확도 떨어져서 고정
    req = driver.page_source
    soup=BeautifulSoup(req, 'html.parser')
    link_list = soup.select(".c_card_info_top > .c_prd_name_row_1 > a")
    link_list = link_list[0:3]
    for link in link_list:
        driver.get(link.get('href'))
        driver.find_element_by_xpath('//*[@id="reviewLi"]/a')
        req = driver.page_source
        soup=BeautifulSoup(req, 'html.parser')
        review_list = soup.select("#reviewObj")
        review_list = review_list[0].select("div.cfix")
        
        for review in review_list:
            
            if not review.find('span', {'class': 'selr_star'}):
                star = ""
            else:
                star = review.find('span', {'class': 'selr_star'}).text
                
            my_dict = {
                "pl_id": df_input.iloc[index]['pl_id'],                      #스펙테이블 아이디
                "pl_model_code": df_input.iloc[index]['pl_model_code'],              #모델코드
                "pl_name": df_input.iloc[index]['pl_name'],                    #모델한글

                "star": star,                                                                #별점
                "market": "11번가",                                                          #구입처(ex 인터파크, 11번가)
                "write_id": review.find('strong', {'class': 'name'}).text,                   #작성자(일부가림처리)
                "upload_day": review.find('span', {'class': 'date'}).text,                   #업로드날짜
                "title":"",                                                                  #리뷰제목 => 11번가는 없음
                "text": review.find('span', {'class': 'summ_conts'}).text,                   #리뷰내용 
                "Target":link.text,                                         #리뷰대상이 되는 상품!!(실제랑 다를 수 있으므로)
                "URL":driver.current_url
            }
            
            crawl_data = crawl_data.append(pd.DataFrame(my_dict,index=[0]))
        
        
    return crawl_data
    

# 초기화 --------------------------------------------
display = Display(visible=0, size=(800, 600))
display.start()
driver = webdriver.Chrome()
driver.implicitly_wait(3)

for i in range(180,len(df_input)):
# for i in range(1):
    crawl_data = crawl_data.append(search_by_category(df_input,crawl_data_none,i,""))
    print(i)
    
crawl_data.to_csv('0409_review_11st_signup.csv',encoding='utf-8-sig')
# Out:
# 0

# %%
import pandas as pd
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 5000)
pd.set_option('display.max_columns', 100)
crawl_data
# Out:
# pandas version:  1.1.5
#   pl_id pl_model_code pl_name             star market         write_id  \
# 0
# 0
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가        som******
# 0     1         A2221   아이폰11                    11번가         kyu*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        mod******
# 0     1         A2221   아이폰11                    11번가        jiy******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        lov******
# 0     1         A2221   아이폰11                    11번가           god***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          dus****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가      mys********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        eun******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가       hae*******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            ak5**
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        a0a******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        myn******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        kkw******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          loo****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         sun*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가          myk****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          bes****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           sht***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가  je3************
# 0     1         A2221   아이폰11                    11번가        jon******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         hai*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         wso*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 4개   11번가         bes*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          kkj****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        lov******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        jun******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          eyg****
# 0     1         A2221   아이폰11                    11번가        may******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가       woo*******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가           mun***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가      mic********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        yan******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          hjb****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         dbq*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         jet*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가      bjh********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           lmj***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가     chu*********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         wva*****
# 0     1         A2221   아이폰11                    11번가        kdy******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           css***
# 0     1         A2221   아이폰11                    11번가          sea****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가       gjt*******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           unn***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          whd****
#
#    upload_day title                                               text  \
# 0
# 0
# 0  2019-12-23        \n금요일 오늘 출발로 오후 1시에 주문하며 당일 오후 6시 반경에 수령하였습니다....
# 0  2020-01-15        \n요약: 토요일 주문시 당일배송 불가 배송지변경하면 헬 \n \n토요일에 주문 혹...
# 0  2019-12-02        \n오후1-2시 사이에 구입했고 오늘 저녁7시쯤 바로 받아서 \n8시 개통완료 했습...
# 0  2020-01-12        \n기변으로 당일 도착으로 주문했습니다 \n주문후 개통에 대한 불안함때문에 1:1 ...
# 0  2019-12-19        \n벼르고 벼르다가 드디어 구매! \n실버 사고싶었는데 몇날 며칠을 기다려도 \n실...
# 0  2020-03-26        \n뽑기운 최악이예요ㅠㅠㅠ \n개통도 전에 카메라렌즈얼룩 발견하고 \n서비스센터 두...
# 0  2020-01-11        \n데이터 옮기는것도 간단하고 \n주문하고 하루만에 바로 받아서 만족스러웠습니다 \...
# 0  2019-12-17        \n대구인데도 12신가 주문하고 4시잉가 받앗어요ㅋㅋㅋ \n겁나 빠름... \n문제...
# 0  2020-04-16        \n선거일이 끼여서 하루 늦었지만 아침일찍 가져다주셔서 점심시간까지 기다리느라 애먹...
# 0  2019-10-25        \n겁나 빨리왔어요 ㅋ 오전 11시에 집으로 배송와서 회사에서 하루종일 핸드폰생각만...
# 0  2019-10-26                   \n25일 바로 개통 할수 있었네요 너무 만족스럽습니다 감사합니다\n
# 0  2020-01-07                     \n저렴하게 잘 구입햇어요 역시 아이폰이네요 ㅎㅎㅎ 너무좋아요\n
# 0  2019-10-25            \n좋아요~ 5년만에 폰 바꿨는데 빠르고 카메라가 역시나 예술입니다.~ +_+\n
# 0  2019-10-25                       \n잘 받았습니다. 실리콘 케이스도 같이 들어 있네요~^^\n
# 0  2019-11-22                                                     \n\n
# 0  2020-06-09                                    \nㅂ배송빠르고 아주 좋습니다!!!\n
# 0  2020-01-08                                                     \n\n
# 0  2020-01-30        \n속았네요. 제가 받은 날이 1월30일 인데 개통 날짜 확인 하니 \n2019년 ...
# 0  2020-04-09        \n리뷰가 얼마없어서 도전정신으로 구매해봤는데, 대만족입니다. \n흠집하나 없고 새...
# 0  2020-01-28        \n오지도 않았는데 배송완료는 뭔가? 출고도 안된 폰을 배송기사 픽업했다고 알림톡 ...
# 0  2020-02-01        \n상품은 아주 깨끗하고 왜 취소했는지 이해가 안가요 11월말에 개통된 제품이긴 해...
# 0  2020-01-31        \n리패키지라고 중고라고 생각하고 구매했는데 깨끗하네요 새제품이라고 생각될 정도이니...
# 0  2020-02-04                                                     \n\n
#
#                           Target  \
# 0
# 0
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0       애플 아이폰 11 프로 256GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0     애플 아이폰 11 프로 맥스 64GB SKT가입
# 0  애플 아이폰 11 프로 256GB 리패키징 SKT가입
# 0  애플 아이폰 11 프로 256GB 리패키징 SKT가입
# 0  애플 아이폰 11 프로 256GB 리패키징 SKT가입
# 0  애플 아이폰 11 프로 256GB 리패키징 SKT가입
# 0  애플 아이폰 11 프로 256GB 리패키징 SKT가입
# 0  애플 아이폰 11 프로 256GB 리패키징 SKT가입
#
#                                                  URL
# 0                                                NaN
# 0                                                NaN
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...

# %%
crawl_data.to_csv('0329_review_11st.csv',encoding='utf-8-sig')

# %% [markdown]
# # 엑셀에서 pl_id 오름차순, text_len(추가후) 내림차순 정렬하고 난 후 => file.csv

# %%
#####################################################################################
######################### 크롤링 데이터 초기화 ######################################
#####################################################################################
my_dict = {
    "pl_id": "",                    #모델영문명
    "text1": "",
    "text2": "",
    "text3": ""
}

filtered_reivew = pd.DataFrame(my_dict,index=[0])
filtered_reivew_none = pd.DataFrame(my_dict,index=[0])
#######################################################################################
#######################################################################################
#######################################################################################

df_output = pd.read_csv('file.csv')
pl_ids = df_output['pl_id'].unique()
models = []
for pl_id in pl_ids:
    is_name = df_output['pl_id'] == pl_id
    model = df_output[is_name]
    model = model[model.text.str.contains(
        r'(용량)|(색)|(사이즈)|(인치)|(화면)|(무게)|(센치)|(배터리)|(카메라)|(메모리)|(성능)|(출시)|(속도)'
        + r'|([0-9]+기가)|(보급형)|(방수)|(무선충전)|(지문인식)|(스크린)|(디스플레이)|(스펙)|(내장)'
        + r'|(외장)|(컬러)|(버튼)|(단자)|(현상)|(듀얼)|(화소)|(내구성)|(발열)|(업데이트)|(C타입)'
    )]    
    
    my_dict = {
    "pl_id": pl_id,                 
    }
    
    if len(model) > 0:
        my_dict["text1"] = model.iloc[0]['text']
    if len(model) > 1:
        my_dict["text2"] = model.iloc[1]['text']
    if len(model) > 2:
        my_dict["text3"] = model.iloc[2]['text']
    
    filtered_reivew = filtered_reivew.append(pd.DataFrame(my_dict,index=[0]))

# %%
filtered_reivew
# Out:
#    pl_id                                              text1  \
# 0
# 0      1  생각보다 하루 늦었지만 그래도 다른 곳보다 훨씬 빠르고 좋아요!!! 할인 받아서 저...
# 0      2  추석연휴 전 주라 배송이 좀 느리긴했네요 - 그래도 콜센터에서 전화와서 기분좋게 기...
# 0      3  백오십에 육박하는 상품을 택배로 받으려니 덜덜...상자에 심플하게 담겨옴. 에어캡이...
# 0      4  친절하시구 배송도 빠르고 개통도 후개통인데 바로 됐고 가격도 방문하는거 제외 인터넷...
# ..   ...                                                ...
# 0    245  싸게 잘 샀습니다. 다만 핸드폰 뒷면이 강화유리로 되어있어서 떨어뜨렸는데 벌써 깨어...
# 0    246                                                NaN
# 0    247                                                NaN
# 0    248                                                NaN
# 0    249   워라밸. 업무와 내 사생활로부터 독립. 현대 사회 생활에서 가장 쉽지 않은 일이죠...
#
#                                                 text2  \
# 0
# 0   동생 사다줬는데 매우 좋아했습니다 특히 색이 너무 이쁘고 그때 마침 4만원인가 세일...
# 0   한달동안 사용해 보면서 너무 너무 만족하면서 사용하고 있어요!!!! 아이폰은 흔히 ...
# 0   XS 쓰다가 넘어왔는데 너무 좋습니다 !특히 터치 후 빠른 반응 제일 만족하고 기존...
# 0   스그 오래걸릴줄알았는데 다행히 월요일에 구매해서 목요일에 받았어용 처음에 온할때 화...
# ..                                                ...
# 0   갤럭시 A7 2017년 제품 잘 받았습니다. 제품 색상이 없어서 아쉽긴 했지만 저렴...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0   중저가 폰 답지 않게 꼭 필요치않은것은 빼서 가격 거품빠져서 좋구요. 노트9은 제가...
#
#                                                 text3
# 0
# 0   아이폰11 퍼플색을 살려고 통신사에 갔습니다. 하지만 퍼플이나 인기 좋은 제품의 색...
# 0   배송도 바로 다음날 받아볼 수 있고 아이폰11pro를 염두해두셨다면 여기서 구입하시...
# 0   저렴하게 구매했습니다 공식인증 애플스토어에서 판매해서 구매하는데 믿음이 갔습니다 어...
# 0   너무 친절하시고 처리도 정말 빨라요..! 해피콜받고 바로 다음날 제품 받아볼 수 있...
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0   참 배송빠르네요..딱하루 걸렸어요..자급제 맞습니다. ..자급제 받으니 ..참 좋네...
#
# [151 rows x 4 columns]

# %%
filtered_reivew.to_csv('filtered_reivew.csv',encoding='utf-8-sig')
