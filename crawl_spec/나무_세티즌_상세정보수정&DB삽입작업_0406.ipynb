# %%
import pandas as pd
import re
a = pd.read_csv("outputs/0406_detail_namu+cetizen.csv")


a.head()
# Out:
#   site_name model_name model_code maker     lauch      os  sell_type  \
# 0       세티즌      아이폰11      A2221    애플  2019. 09  iOS 13        NaN
# 1       세티즌    아이폰11프로      A2215    애플  2019. 09  iOS 13        NaN
# 2       세티즌  아이폰11프로맥스      A2218    애플  2019. 09  iOS 13        NaN
# 3       세티즌      아이폰Xs      A2097    애플  2018. 09  iOS 12        NaN
# 4       세티즌   아이폰Xs 맥스      A2101    애플  2018. 09  iOS 12        NaN
#
#    display_inch display_centi panel_type  ... battery_char  \
# 0           NaN           6.1        IPS  ...  급속충전\r\n일체형
# 1           NaN           5.8       OLED  ...  급속충전\r\n일체형
# 2           NaN           6.5       OLED  ...  급속충전\r\n일체형
# 3           NaN           5.8       OLED  ...  급속충전\r\n일체형
# 4           NaN           6.5       OLED  ...  급속충전\r\n일체형
#
#   battery_mount_method charge_support high_speed_charge  wireless_charge  \
# 0                  NaN            NaN               NaN          무선충전 지원
# 1                  NaN            NaN               NaN          무선충전 지원
# 2                  NaN            NaN               NaN          무선충전 지원
# 3                  NaN            NaN               NaN          무선충전 지원
# 4                  NaN            NaN               NaN          무선충전 지원
#
#   color length  width thickness weight
# 0   NaN   75.7  150.9       8.3   194g
# 1   NaN   71.4    144       8.1   188g
# 2   NaN   77.8    158       8.1   226g
# 3   NaN   70.9  143.6       7.7   177g
# 4   NaN   77.4  157.5       7.9   208g
#
# [5 rows x 86 columns]

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# MySQL Connector using pymysql
pymysql.install_as_MySQLdb()
import MySQLdb



engine = create_engine("mysql+mysqldb://root:"+"123123"+"@localhost/gidseller", encoding='utf-8')
conn = engine.connect()

a.to_sql(name='detail_list', con=engine, if_exists='append', index=False)
