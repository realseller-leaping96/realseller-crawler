# %%
import pandas as pd
import re
a = pd.read_csv("0408_danawa_spec.csv")


a.head()
# Out:
#   site_name     model_name model_code  \
# 0       다나와          아이폰11      A2221
# 1       다나와      아이폰11 Pro      A2215
# 2       다나와  아이폰11 Pro Max      A2218
# 3       다나와          아이폰Xs      A2097
# 4       다나와      아이폰Xs Max      A2101
#
#                                                maker  lauch           os  \
# 0  \nAPPLE (\n\t\t\t\t\t\t\t제조사 웹사이트 바로가기)\n\t\t\...    NaN  출시OS: iOS13
# 1  \nAPPLE (\n\t\t\t\t\t\t\t제조사 웹사이트 바로가기)\n\t\t\...    NaN  출시OS: iOS13
# 2  \nAPPLE (\n\t\t\t\t\t\t\t제조사 웹사이트 바로가기)\n\t\t\...    NaN  출시OS: iOS13
# 3  \nAPPLE (\n\t\t\t\t\t\t\t제조사 웹사이트 바로가기)\n\t\t\...    NaN  출시OS: iOS12
# 4  \nAPPLE (\n\t\t\t\t\t\t\t제조사 웹사이트 바로가기)\n\t\t\...    NaN  출시OS: iOS12
#
#    sell_type  display_inch   display_centi panel_type  ... battery_char  \
# 0  통신사가입-SKT           NaN  15.49cm(6.1인치)    IPS-LCD  ...          NaN
# 1    공기계-새제품           NaN  14.73cm(5.8인치)       OLED  ...          NaN
# 2    공기계-새제품           NaN  16.51cm(6.5인치)       OLED  ...          NaN
# 3     가개통/중고           NaN  14.73cm(5.8인치)   S-AMOLED  ...          NaN
# 4     가개통/중고           NaN  16.51cm(6.5인치)   S-AMOLED  ...          NaN
#
#   battery_mount_method charge_support high_speed_charge wireless_charge  \
# 0               배터리일체형          최대18W            고속충전지원          Qi무선충전
# 1               배터리일체형          최대18W         USB PD3.0          Qi무선충전
# 2               배터리일체형          최대18W         USB PD3.0          Qi무선충전
# 3               배터리일체형          최대15W            고속충전지원  Qi무선충전: 최대7.5W
# 4               배터리일체형          최대15W            고속충전지원  Qi무선충전: 최대7.5W
#
#    color     length       width thickness   weight
# 0    NaN  가로:75.7mm  세로:150.9mm  두께:8.3mm  무게:194g
# 1    NaN  가로:71.4mm    세로:144mm  두께:8.1mm  무게:188g
# 2    NaN  가로:77.8mm    세로:158mm  두께:8.1mm  무게:226g
# 3    NaN  가로:70.9mm  세로:143.6mm  두께:7.7mm  무게:177g
# 4    NaN  가로:77.4mm  세로:157.5mm  두께:7.7mm  무게:208g
#
# [5 rows x 86 columns]

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# MySQL Connector using pymysql
pymysql.install_as_MySQLdb()
import MySQLdb



engine = create_engine("mysql+mysqldb://root:"+"123123"+"@localhost/gidseller", encoding='utf-8')
conn = engine.connect()

a.to_sql(name='detail_list', con=engine, if_exists='append', index=False)
