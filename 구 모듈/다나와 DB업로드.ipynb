# %%
import pandas as pd
import re
a = pd.read_csv("outputs/0409_detail_통합.csv")


a.head()
# Out:
#    사이트명            모델명   모델코드   제조회사  출시일                운영체제 판매방식  화면크기(센치)  \
# 0  나무위키          아이폰11  A2221  apple  NaN       iOS 13.0 → 14  NaN       NaN
# 1  나무위키      아이폰11 Pro  A2215  apple  NaN       iOS 13.0 → 14  NaN       NaN
# 2  나무위키  아이폰11 Pro Max  A2218  apple  NaN       iOS 13.0 → 14  NaN       NaN
# 3  나무위키          아이폰Xs  A2097  apple  NaN  iOS 12.0 → 13 → 14  NaN       NaN
# 4  나무위키      아이폰Xs Max  A2101  apple  NaN  iOS 12.0 → 13 → 14  NaN       NaN
#
#   화면크기(인치)           패널종류  ...                          배터리특징 배터리장착방식 충전지원  \
# 0    6.1인치    IPS TFT-LCD  ...  USB Power Delivery 2.0 (18 W)     NaN  NaN
# 1    5.8인치  HDR 지원 AMOLED  ...  USB Power Delivery 2.0 (18 W)     NaN  NaN
# 2    6.5인치  HDR 지원 AMOLED  ...  USB Power Delivery 2.0 (18 W)     NaN  NaN
# 3    5.8인치  HDR 지원 AMOLED  ...   USB Power Delivery 2.0 (18W)     NaN  NaN
# 4    6.5인치  HDR 지원 AMOLED  ...  USB Power Delivery 2.0 (18 W)     NaN  NaN
#
#   고속충전기술  무선충전                                 색상    가로     세로       두께  \
# 0    NaN   NaN  블랙, 화이트, 옐로, 그린, 퍼플, (PRODUCT)RED  75.7  150.9   8.3 mm
# 1    NaN   NaN         스페이스 그레이, 실버, 골드, 미드나이트 그린  71.4    144   8.1 mm
# 2    NaN   NaN         스페이스 그레이, 실버, 골드, 미드나이트 그린  77.8    158   8.1 mm
# 3    NaN   NaN                   스페이스 그레이, 실버, 골드  70.9  143.6   7.7 mm
# 4    NaN   NaN                   스페이스 그레이, 실버, 골드  77.4  157.5   7.7 mm
#
#        무게
# 0   194 g
# 1    188g
# 2   226 g
# 3   177 g
# 4   208 g
#
# [5 rows x 86 columns]

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# MySQL Connector using pymysql
pymysql.install_as_MySQLdb()
import MySQLdb



engine = create_engine("mysql+mysqldb://root:"+"123123"+"@localhost/gidseller", encoding='utf-8')
conn = engine.connect()

a.to_sql(name='phone_list', con=engine, if_exists='append', index=False)
