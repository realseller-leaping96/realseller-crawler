# %% [markdown]
# # 검수작업 이전

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time
import re
import os

#######################내가 정의한 모듈##############################################
from module.namuwiki.detail_df_init import df_init #출력할 데이터 프레임 형식 정의 =>  DataFrame 리턴
from module.cetizen import main as cetizen
from module.danawa import main as danawa



#######################입력 파일 로드################################

df_input = pd.read_csv('../input_raw.csv')
df_input=df_input.fillna('')
#print(df_input.iloc[102])

#######################출력 형식 로드################################
# df_output = df_init()
df_output = pd.DataFrame(index=range(0), columns=['모델명', '모델코드','제조회사','타겟','URL'])

######################셀레니움 로드################################
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
chrome_options.add_argument("--headless")
# driver  = webdriver.Chrome(options = chrome_options)
driver  = webdriver.Chrome()
driver.implicitly_wait(3)

#######################크롤링 파트 (나무위키)################################

#######################크롤링 파트 (세티즌)################################
# df_output = cetizen.URL(df_input, driver, df_output, 0,148)
# time.sleep(10)
# df_output = cetizen.URL(df_input, driver, df_output, 148,len(df_input))

#######################크롤링 파트 (다나와)################################
df_output = danawa.URL(df_input, driver, df_output, 19,len(df_input))

#######################크롤링 데이터 저장################################
# df_output.to_csv("add_0416_s.csv", encoding = "utf-8-sig")
# Out:
# 0 http://prod.danawa.com/info/?pcode=9686247&keyword=%EC%95%84%EC%9D%B4%ED%8F%B011&cate=122514
# 1 http://prod.danawa.com/info/?pcode=9686247&keyword=%EC%95%84%EC%9D%B4%ED%8F%B011%20Pro&cate=122514
# 2 http://prod.danawa.com/info/?pcode=9686247&keyword=%EC%95%84%EC%9D%B4%ED%8F%B011%20Pro%20Max&cate=122514
# 3 http://prod.danawa.com/info/?pcode=6541437&keyword=%EC%95%84%EC%9D%B4%ED%8F%B0Xs&cate=122515
# 4 http://prod.danawa.com/info/?pcode=6576244&keyword=%EC%95%84%EC%9D%B4%ED%8F%B0Xs%20Max&cate=12215709
# 5 http://prod.danawa.com/info/?pcode=6574142&keyword=%EC%95%84%EC%9D%B4%ED%8F%B0Xr&cate=12215709
# 6 http://prod.danawa.com/info/?pcode=5789355&keyword=%EC%95%84%EC%9D%B4%ED%8F%B0X&cate=12215709
# 7 http://prod.danawa.com/info/?pcode=5615613&keyword=%EC%95%84%EC%9D%B4%ED%8F%B08&cate=12215709
# 8 http://prod.danawa.com/info/?pcode=5811641&keyword=%EC%95%84%EC%9D%B4%ED%8F%B08%20Plus&cate=12215709
# ...

# %%
df_output
# Out:
#               모델명      모델코드     제조회사          타겟  \
# 0           아이폰11     A2221    apple       아이폰11
# 0       아이폰11 Pro     A2215    apple     아이폰11프로
# 0   아이폰11 Pro Max     A2218    apple   아이폰11프로맥스
# 0           아이폰Xs     A2097    apple       아이폰Xs
# 0       아이폰Xs Max     A2101    apple    아이폰Xs 맥스
# ..            ...       ...      ...         ...
# 0         옵티머스 3D  LG-SU760       lg      옵티머스3D
# 0      옵티머스 3D 큐브  LG-SU870       lg  옵티머스 3D 큐브
# 0         옵티머스 EX  LG-SU880       lg      옵티머스EX
# 0           넥서스 S   Nexus S  samsung       넥서스 S
# 0          갤럭시 네오  SHW-M220  samsung      갤럭시 네오
#
#                                                   URL 사이트명
# 0   https://review.cetizen.com/7214/view/3/7214/re...  세티즌
# 0   https://review.cetizen.com/7217/view/3/7217/re...  세티즌
# 0   https://review.cetizen.com/7220/view/3/7220/re...  세티즌
# 0   https://review.cetizen.com/6915/view/3/6915/re...  세티즌
# 0   https://review.cetizen.com/6916/view/3/6916/re...  세티즌
# ...

# %%
df_output.to_csv("output_add.csv", encoding = "utf-8-sig")

# %%
df_output = danawa.URL(df_input, driver, df_output, 0,len(df_input))
