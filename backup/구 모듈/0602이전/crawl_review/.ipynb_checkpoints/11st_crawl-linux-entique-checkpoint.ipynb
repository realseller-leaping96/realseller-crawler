# %% [markdown]
# # 1. 엑셀데이터 불러오기

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import numpy as np
import re
import os
from pyvirtualdisplay import Display
from selenium import webdriver
import time

df_input = pd.read_csv('../input_data_~0407 (version 1).csv')
df_input.iloc[0]
# Out:
# pl_id                                          1
# pl_maker                                   apple
# pl_model_code                              A2221
# pl_name                                    아이폰11
# pl_model_name                           iphone11
# Unnamed: 5                                   NaN
# 나무위키링크단품         https://namu.wiki/w/iPhone%2011
# Unnamed: 7                                   NaN
# Unnamed: 8                                   NaN
# Unnamed: 9                                   NaN
# Name: 0, dtype: object

# %% [markdown]
# # 2. 리뷰크롤링

# %%
import time
#####################################################################################
######################### 크롤링 데이터 초기화 ######################################
#####################################################################################
my_dict = {
    "pl_id": "",                      #스펙테이블 아이디
    "pl_model_code": "",              #모델코드
    "pl_name": "",                    #모델영문명
    
    "star": "",                       #별점
    "market": "",                     #구입처(ex 인터파크, 11번가)
    "write_id": "",                   #작성자(일부가림처리)
    "upload_day": "",                 #업로드날짜
    "title":"",                       #리뷰제목 
    "text": "",                        #리뷰내용 
    "Target":""                       #리뷰대상이 되는 상품!!(실제랑 다를 수 있으므로)
}

crawl_data = pd.DataFrame(my_dict,index=[0])
crawl_data_none = pd.DataFrame(my_dict,index=[0])
#######################################################################################
#######################################################################################
#######################################################################################

def search_by_category(df_input,crawl_data,index,option):
    url1 = 'https://search.11st.co.kr/Search.tmall?method=getCatalogPrdSearch&catalogYN=Y&kwd='
    driver.get(url1+df_input.iloc[index]['pl_name']+"#chkCtgrNo%%1002724%%중고폰%%5$$")
    driver.implicitly_wait(3)
    
    
    #페이지에 있는 링크 다 긁어오기, 일단 스크롤기능 추가안해서 5개만 가져옴 => 5개 넘어가면 검색정확도 떨어져서 고정
    req = driver.page_source
    soup=BeautifulSoup(req, 'html.parser')
    link_list = soup.select(".c_card_info_top > .c_prd_name_row_1 > a")
    link_list = link_list[0:3]
    for link in link_list:
        driver.get(link.get('href'))
        driver.find_element_by_xpath('//*[@id="reviewLi"]/a')
        req = driver.page_source
        soup=BeautifulSoup(req, 'html.parser')
        review_list = soup.select("#reviewObj")
        review_list = review_list[0].select("div.cfix")
        
        for review in review_list:
            
            if not review.find('span', {'class': 'selr_star'}):
                star = ""
            else:
                star = review.find('span', {'class': 'selr_star'}).text
                
            my_dict = {
                "pl_id": df_input.iloc[index]['pl_id'],                      #스펙테이블 아이디
                "pl_model_code": df_input.iloc[index]['pl_model_code'],              #모델코드
                "pl_name": df_input.iloc[index]['pl_name'],                    #모델한글명

                "star": star,                                                                #별점
                "market": "11번가",                                                          #구입처(ex 인터파크, 11번가)
                "write_id": review.find('strong', {'class': 'name'}).text,                   #작성자(일부가림처리)
                "upload_day": review.find('span', {'class': 'date'}).text,                   #업로드날짜
                "title":"",                                                                  #리뷰제목 => 11번가는 없음
                "text": review.find('span', {'class': 'summ_conts'}).text,                   #리뷰내용 
                "Target":link.text,                                         #리뷰대상이 되는 상품!!(실제랑 다를 수 있으므로)
                "URL":driver.current_url
            }
            
            crawl_data = crawl_data.append(pd.DataFrame(my_dict,index=[0]))
        
        
    return crawl_data
    

# 초기화 --------------------------------------------
display = Display(visible=0, size=(800, 600))
display.start()
driver = webdriver.Chrome()
driver.implicitly_wait(3)

for i in range(180,len(df_input)):
    crawl_data = crawl_data.append(search_by_category(df_input,crawl_data_none,i,""))
    print(i)
    
# crawl_data.to_csv('0326_review_11st.csv',encoding='utf-8-sig')
# Out:
# 0

# %%
import pandas as pd
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 5000)
pd.set_option('display.max_columns', 100)
crawl_data
# Out:
# pandas version:  1.1.5
#   pl_id pl_model_code pl_name             star market           write_id  \
# 0
# 0
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            koa****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          jos******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가             mys***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 4개   11번가         won*******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가  S|5**************
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가             eot***
# 0     1         A2221   아이폰11                    11번가          wit******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            pp0****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가             fre***
# 0     1         A2221   아이폰11                    11번가           kuz*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 4개   11번가         rai*******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가          kim******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         bla*******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 4개   11번가            eas****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            99o****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        san********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           qwe*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가             war***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 4개   11번가             vr4***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            pyj****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           a03*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가  nom**************
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가       tha*********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           qbx*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           ohm*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가         jun*******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가       cof*********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가             unj***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            tjw****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            hen****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          wol******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가            n_a****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 4개   11번가             bro***
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가        chu********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가          son******
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가            lsm****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 3개   11번가            eg1****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가       thd*********
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           com*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 5개   11번가           ssi*****
# 0     1         A2221   아이폰11  판매자 평점 별5개 중 4개   11번가           k61*****
#
#    upload_day title                                               text  \
# 0
# 0
# 0  2020-03-07        \n사실 배송이 정말 늦었습니다만 거의 뭐 직구폰 구매하는 기분이었습니다 서울에서 ...
# 0  2020-07-16        \n4시 전에 주문하니 담날 받았어요. \n1년도 안되서 6s 배터리 불편하기 시작...
# 0  2020-11-30        \n대리점 구매시 카드할인, 요금제 강요,약정 등등 불편한 내용이 생겨서 처음으로 ...
# 0  2020-12-20        \n화이트로 주문했는데 검수시 불량이 있어서 그린으로 교환되어 배송 받았어요. 크리...
# 0  2020-09-05        \n우선 배송은 태풍이랑 겹쳐서 그런지는 몰라도 좀 걸렸어요 택배 여니까 폰마블 박...
# 0  2020-06-04        \n제가 옆면 기스는 상관없으니 화면엔 기스 1도없는걸로 달라고했는데 진짜 저부분 ...
# 0  2020-04-04        \n구매후 몇일뒤 전화하는데 폰이 갑자기 뜨거워지고 \n화면전체가 파랗게 변해서 껏...
# 0  2021-02-24        \n아들폰이라,,,아이폰은 좀복잡하네요 먼저구경좀하려다가 포기,,,,폰은깨끗하고 이...
# 0  2020-06-04        \n음 가개통 새제품이란 제품박스 오프하여 사용한 제품이란걸 이번에 처음 알았습니다...
# 0  2021-03-05        \n전체적으로 양호하나 액정 센서 밑부분에 미세한 찍힘이 어두운데서는 잘안보이나 밝...
# 0  2020-06-30        \n핸드폰은 좋아요. 깨끗하고 새것 같아요. \n충전 케이블을 기본으로 주시는거 제...
# 0  2020-02-26        \n택배는 하루정도 쉬다가 배송받았구요 \n기기 자체로 만족은 별4개 이상입니다만 ...
# 0  2021-03-24        \n딸아이가 아이폰11로 변경하고싶다고해서 고민하다가 \n 샀는데 생각보다 괜찮아요...
# 0  2020-06-14        \n배터리 성능도 100%이고 흠집도 없는 건 좋은데 유심 끼웠는데도 서비스 없음이...
# 0  2020-07-09        \n와이프가 사용하는 아이폰6s가. .배터리가. .넘 빨리 닳는다구. .징징대길래며...
# 0  2020-09-06        \n배터리 성능이 80%내외라고 명시되어있는데 받고보니 96%로 성능이 아주 좋아서...
# 0  2021-01-12        \n아직 백업은 못했고요, 외관 상태는 완전 새폰과 구분 안될 정도로 깨끗한 상태예...
# 0  2019-04-10        \n블루 재고가 없어서 화이트로 받은것 말고는 \n2일째 쓰고있는데 아직까진 하자없...
# 0  2020-02-26        \n음 완전 새것처럼 다 좋은데 / 터치가 잘 안먹음 가끔 리부팅해서 해결할 에러가...
# 0  2021-02-05        \n생각보다 너무 좋아서 사길 잘 할것 같아요ㅎㅎ 현재폰 액정이 깨저서 나중에 갤럭...
# 0  2020-06-29        \n정말 고민끝에 여러 후기를 보고 저의 느낌 그리고 정식리퍼제품이란 확신 믿고 주...
# 0  2020-07-17        \n화요일 오후에 구매해서 목요일 정오쯤 받았어요. \n택배 기사님이 연락도 없이 ...
# 0  2017-12-16        \n제품은 아주 좋습니다. 작년에 'ㅈ' 쇼핑몰에서 홍콩 직구로 구입했는데 고장이 ...
# 0  2019-12-23        \n리퍼폰이라서 솔직히 성능이 의심스러웠지만 \n정가의 반 가격에 외관상 문제없는 ...
# 0  2020-10-26        \n16시에 주문했는데 다음날 오전중에 도착했어요. 배송 엄청 빨랐고 상품도 완전 ...
# 0  2020-07-22        \n원래 일주일 넘게 걸린다고 하셨는데 취소건이 생겨서 이틀만에 왔어요! 처음에는 ...
# 0  2020-01-08        \n일단 하루라도 빨리 출고해주셔서 진심 감사드립니다. \n \n11번가에서 다른 ...
# 0  2018-11-01        \n생각보다 빨리 수령했어요. \n아이팟 대용으로도 사용 가능할 예정이라 64기가 ...
# 0  2020-10-20        \n솔직히 11번가 이런데서 핸드폰첨사바서 너무 불안했는데 카톡으로 연락했더니 성의...
# 0  2020-06-09        \n실사용 후기를 쓰려고 후기가 늦어졌습니다 지금 일주일 넘게 쓰고 있는데 완전 만...
# 0  2020-01-21        \n첫 아이폰이라 혹시라도 이상있으면 어떻게 해야하나 걱정했는데 그런 걱정 싹 덜어...
# 0  2020-01-30        \n전에 쓰던 폰이 점점 맛가기 시작해서 \n한달여간 살지말지 고민하다가 결국 질렀...
# 0  2019-10-02        \n리퍼폰이라 그런지 새폰같네요 ^^ \n \n아이폰7쓰다가 xs로 넘어오니 신세계...
# 0  2017-08-14        \n정말 거짓말 안보태고 친절하심 \n시원한 물과 아이스 주면서 쉬게 해주고 다 해...
# 0  2019-12-31        \n리퍼폰 엄청 찾아보다가 여기서 구매했습니다 혹시나 비정품짜집기 해서 새상품으로 ...
# 0  2018-01-09        \n진짜 다 좋은데 내껀 동영상볼때 무한버퍼랑 영상다운속도가 엄청 심각함ㅋㅋ 수리센...
# 0  2020-06-12        \n배송이 생각보다 오래 걸립니다 \n송장 받고 실제 제품은 6일 정도 걸려 늦은 ...
# 0  2020-01-16        \n아이폰 6s 2년 반 사용하다 배터리 때문에 xs로 바꿨어용~~~ 90만원이라 ...
# 0  2020-01-15        \n애플 아이폰 xs 공기계, 스페이스 그레이 구매했어용 !! 2020년 7월까지 ...
# 0  2020-09-18        \n업체에서는 신속하게 발송을 하신거 같으나 택배사에서 4일정도 소요되었어요. 오늘...
# 0  2020-08-23                                 \n재고가 없다고 해서 오래 기다렸어요.\n
#
#                          Target  \
# 0
# 0
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0        애플 아이폰 11 64GB 공기계(중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0    애플 아이폰 11 프로 64GB 공기계 (중고)
# 0  애플 아이폰 11 프로 맥스 64GB 공기계(중고)
#
#                                                  URL
# 0                                                NaN
# 0                                                NaN
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...
# 0  https://www.11st.co.kr/catalog/catalogDetail.t...

# %%
crawl_data.to_csv('review_data999.csv.csv',encoding='utf-8-sig')

# %% [markdown]
# # 엑셀에서 pl_id 오름차순, text_len(추가후) 내림차순 정렬하고 난 후 => file.csv

# %%
#####################################################################################
######################### 크롤링 데이터 초기화 ######################################
#####################################################################################
my_dict = {
    "pl_id": "",                    #모델영문명
    "text1": "",
    "text2": "",
    "text3": ""
}

filtered_reivew = pd.DataFrame(my_dict,index=[0])
filtered_reivew_none = pd.DataFrame(my_dict,index=[0])
#######################################################################################
#######################################################################################
#######################################################################################

df_output = pd.read_csv('file.csv')
pl_ids = df_output['pl_id'].unique()
models = []
for pl_id in pl_ids:
    is_name = df_output['pl_id'] == pl_id
    model = df_output[is_name]
    model = model[model.text.str.contains(
        r'(용량)|(색)|(사이즈)|(인치)|(화면)|(무게)|(센치)|(배터리)|(카메라)|(메모리)|(성능)|(출시)|(속도)'
        + r'|([0-9]+기가)|(보급형)|(방수)|(무선충전)|(지문인식)|(스크린)|(디스플레이)|(스펙)|(내장)'
        + r'|(외장)|(컬러)|(버튼)|(단자)|(현상)|(듀얼)|(화소)|(내구성)|(발열)|(업데이트)|(C타입)'
    )]    
    
    my_dict = {
    "pl_id": pl_id,                 
    }
    
    if len(model) > 0:
        my_dict["text1"] = model.iloc[0]['text']
    if len(model) > 1:
        my_dict["text2"] = model.iloc[1]['text']
    if len(model) > 2:
        my_dict["text3"] = model.iloc[2]['text']
    
    filtered_reivew = filtered_reivew.append(pd.DataFrame(my_dict,index=[0]))

# %%
filtered_reivew
# Out:
#    pl_id                                              text1  \
# 0
# 0      1  생각보다 하루 늦었지만 그래도 다른 곳보다 훨씬 빠르고 좋아요!!! 할인 받아서 저...
# 0      2  추석연휴 전 주라 배송이 좀 느리긴했네요 - 그래도 콜센터에서 전화와서 기분좋게 기...
# 0      3  백오십에 육박하는 상품을 택배로 받으려니 덜덜...상자에 심플하게 담겨옴. 에어캡이...
# 0      4  친절하시구 배송도 빠르고 개통도 후개통인데 바로 됐고 가격도 방문하는거 제외 인터넷...
# ..   ...                                                ...
# 0    245  싸게 잘 샀습니다. 다만 핸드폰 뒷면이 강화유리로 되어있어서 떨어뜨렸는데 벌써 깨어...
# 0    246                                                NaN
# 0    247                                                NaN
# 0    248                                                NaN
# 0    249   워라밸. 업무와 내 사생활로부터 독립. 현대 사회 생활에서 가장 쉽지 않은 일이죠...
#
#                                                 text2  \
# 0
# 0   동생 사다줬는데 매우 좋아했습니다 특히 색이 너무 이쁘고 그때 마침 4만원인가 세일...
# 0   한달동안 사용해 보면서 너무 너무 만족하면서 사용하고 있어요!!!! 아이폰은 흔히 ...
# 0   XS 쓰다가 넘어왔는데 너무 좋습니다 !특히 터치 후 빠른 반응 제일 만족하고 기존...
# 0   스그 오래걸릴줄알았는데 다행히 월요일에 구매해서 목요일에 받았어용 처음에 온할때 화...
# ..                                                ...
# 0   갤럭시 A7 2017년 제품 잘 받았습니다. 제품 색상이 없어서 아쉽긴 했지만 저렴...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0   중저가 폰 답지 않게 꼭 필요치않은것은 빼서 가격 거품빠져서 좋구요. 노트9은 제가...
#
#                                                 text3
# 0
# 0   아이폰11 퍼플색을 살려고 통신사에 갔습니다. 하지만 퍼플이나 인기 좋은 제품의 색...
# 0   배송도 바로 다음날 받아볼 수 있고 아이폰11pro를 염두해두셨다면 여기서 구입하시...
# 0   저렴하게 구매했습니다 공식인증 애플스토어에서 판매해서 구매하는데 믿음이 갔습니다 어...
# 0   너무 친절하시고 처리도 정말 빨라요..! 해피콜받고 바로 다음날 제품 받아볼 수 있...
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0   참 배송빠르네요..딱하루 걸렸어요..자급제 맞습니다. ..자급제 받으니 ..참 좋네...
#
# [151 rows x 4 columns]

# %%
filtered_reivew.to_csv('filtered_reivew.csv',encoding='utf-8-sig')
